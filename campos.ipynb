# %%
from ortools.linear_solver import pywraplp
from ortools.linear_solver.pywraplp import Solver, Variable, Objective
# Out:
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\zlib1.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\abseil_dll.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\utf8_validity.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\re2.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\libprotobuf.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\highs.dll...
# load c:\Users\guifa\zcomputacao\unifor\tcc\venv\Lib\site-packages\ortools\.libs\ortools.dll...

# %%
#declara o solver: se PLI, usa-se SCIP; se PL, usa-se GLOP.
solver: Solver = pywraplp.Solver.CreateSolver('GLOP')

#declara um número muito grande para ser usado no modelo
infinity = solver.infinity()

# %%
#declara as variáveis do modelo: IntVar para inteira; NumVar para fracionárias; BoolVar para binárias.
x: Variable = solver.IntVar(500,infinity,"m2 reservados para o cultivo de arroz")
y: Variable = solver.IntVar(500,infinity,"m2 reservados para o cultivo de soja")

# %%
#declara a função objetivo
objetivo: Objective = solver.Objective()
objetivo.SetCoefficient(x, 5)
objetivo.SetCoefficient(y, 8)
objetivo.SetMaximization()

# %%
#declara restrições
restricao_1 = solver.Add(x + y <= 2000)

# %%
status = solver.Solve()

if status == pywraplp.Solver.OPTIMAL:
    print("Solução Ótima Encontrada!")
    print(f"{x.name()}: {x.solution_value()}")
    print(f"{y.name()}: {y.solution_value()}")
    print(f"Lucro máximo: {objetivo.Value()}")
elif status == pywraplp.Solver.INFEASIBLE:
    print("O modelo não possui solução viável.")
elif status == pywraplp.Solver.UNBOUNDED:
    print("O modelo é ilimitado.")
else:
    print("Otimização não foi concluída corretamente.")
# Out:
# Solução Ótima Encontrada!
# m2 reservados para o cultivo de arroz: 500.0
# m2 reservados para o cultivo de soja: 1500.0
# Lucro máximo: 14500.0

# %%
#exibe o modelo
print(solver.ExportModelAsLpFormat(False))
# Out:
# \ Generated by MPModelProtoExporter
# \   Name             :
# \   Format           : Free
# \   Constraints      : 1
# \   Variables        : 2
# \     Binary         : 0
# \     Integer        : 2
# \     Continuous     : 0
# Maximize
#  Obj: +5 m2_reservados_para_o_cultivo_de_arroz +8 m2_reservados_para_o_cultivo_de_soja
# Subject to
#  auto_c_000000000: +1 m2_reservados_para_o_cultivo_de_arroz +1 m2_reservados_para_o_cultivo_de_soja  <= 2000
# Bounds
#  500 <= m2_reservados_para_o_cultivo_de_arroz <= inf
#  500 <= m2_reservados_para_o_cultivo_de_soja <= inf
# Generals
#  m2_reservados_para_o_cultivo_de_arroz
#  m2_reservados_para_o_cultivo_de_soja
# End

# %% [markdown]
# Team Maia
